# %% [markdown]
# * 482 Lisence Key Formatting

# %%
chars = []

        for ch in s:
            if ch != '-':
                chars.append(ch.upper())
        
        res = []
        count = 0

        for i in range(len(chars) - 1, -1, -1):
            res.append(chars[i])
            count += 1

            if count == k and i != 0:
                res.append('-')
                count = 0
                
        return ''.join(reversed(res))
